# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread("images/simple.jpg")
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray")
plt.show()

# %%
sift = cv.SIFT_create()
kp = sift.detect(gray, None)
img = cv.drawKeypoints(gray, kp, img)
plt.imshow(img)
