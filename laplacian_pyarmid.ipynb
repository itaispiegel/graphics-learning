# %%
import numpy as np
from PIL import Image, ImageFilter

# %%
img = Image.open("images/lenna.png")
blurred = img.filter(ImageFilter.GaussianBlur(0.45))
diff = np.asarray(img) - np.asarray(blurred)
new_img = Image.fromarray(diff)
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
